# %%
import dwh_sql_queries as dsq

# %%
#!PGPASSWORD=student createdb -h 127.0.0.1 -U koray_v2 pagila
#!PGPASSWORD=student psql -q -h 127.0.0.1 -U koray_v2 -d pagila -f Data/pagila-schema.sql

#!PGPASSWORD=student psql -q -h 127.0.0.1 -U koray_v2 -d pagila -f /Users/koray/Documents/GitHub/Udacity_DE/P3_AWS/pagila-insert-data.sql

# %%
# %reload_ext sql
conn_string = dsq.create_connection()
# %sql $conn_string
# Out:
# postgresql://koray_v2:password@127.0.0.1:5432/pagila

# %%
def magic_sql(tables):
    for table in tables:
        # %sql $table

# %%
magic_sql(dsq.drop_star_tables)
print("Star schema tables are dropped")
magic_sql(dsq.create_star_tables)
print("Star schema tables are created")
# Out:
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
# Star schema tables are dropped
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# Done.
# Star schema tables are created

# %%
# %%time
# %%sql
SELECT COLUMN_NAME, DATA_TYPE, IS_NULLABLE, COLUMN_DEFAULT
  FROM INFORMATION_SCHEMA.COLUMNS
  WHERE table_name = 'dimdate'
# Out:
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# 8 rows affected.
# CPU times: user 2.2 ms, sys: 4.45 ms, total: 6.65 ms
# Wall time: 78.9 ms
# [('date_key', 'integer', 'NO', None),
#  ('date', 'date', 'NO', None),
#  ('year', 'integer', 'YES', None),
#  ('quarter', 'integer', 'YES', None),
#  ('month', 'integer', 'YES', None),
#  ('day', 'integer', 'YES', None),
#  ('week', 'integer', 'YES', None),
#  ('is_weekend', 'boolean', 'YES', None)]

# %%
# %sql select * from dimdate
# Out:
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# 0 rows affected.
# []

# %%
# %sql select * from payment limit 10
# Out:
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2020, 1, 24, 22, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2020, 1, 25, 16, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2020, 1, 28, 22, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2020, 1, 29, 1, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2020, 1, 29, 9, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16055, 269, 2, 1099, Decimal('2.99'), datetime.datetime(2020, 1, 31, 13, 23, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16056, 270, 1, 193, Decimal('1.99'), datetime.datetime(2020, 1, 26, 6, 10, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16057, 270, 1, 1040, Decimal('4.99'), datetime.datetime(2020, 1, 31, 5, 3, 42, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16058, 271, 1, 1096, Decimal('8.99'), datetime.datetime(2020, 1, 31, 12, 59, 15, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None))),
#  (16059, 272, 1, 33, Decimal('0.99'), datetime.datetime(2020, 1, 25, 3, 47, 17, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=60, name=None)))]

# %%
INSERT INTO dimdate (date_key,date,year,quarter,month,day,week,is_weekend)
select 
    # as date_key,
    date,

# %%
#still not only user created tables but close enough
# %sql select * from information_schema.tables where table_schema = 'public' AND lower(table_type) like '%base%'
# Out:
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# 25 rows affected.
# [('pagila', 'public', 'dimdate', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'factsales', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'dimcustomer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'dimmovie', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'dimstore', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'inventory', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment_p2020_01', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment_p2020_04', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'film_actor', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'address', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'city', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'actor', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'category', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'country', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'customer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment_p2020_02', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment_p2020_03', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'film', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'film_category', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'language', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment_p2020_06', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'payment_p2020_05', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'rental', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('pagila', 'public', 'staff', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# all user_created tables are under public schema ()
# %sql select distinct table_schema from information_schema.tables
# Out:
#  * postgresql://koray_v2:***@127.0.0.1:5432/pagila
# 3 rows affected.
# [('public',), ('pg_catalog',), ('information_schema',)]
